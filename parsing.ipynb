# %%
from edgar_functions import *
from headers import headers
ticker = "WSM"

# %%
accn = get_filtered_filings(ticker, ten_k=True, just_accession_numbers=True, headers=headers)
acc_num = accn.iloc[0].replace('-','')
soup = get_statement_soup(ticker, acc_num, 'balance_sheet', headers=headers, statement_keys_map=statement_keys_map)

# %%
process_one_statement(ticker, acc_num, 'balance_sheet')
# Out:
#                                                     2023-01-29  2022-01-30
# us-gaap_AssetsCurrentAbstract                              NaN         NaN
# us-gaap_CashAndCashEquivalentsAtCarryingValue          367,344     850,338
# us-gaap_ReceivablesNetCurrent                          115,685     131,683
# us-gaap_InventoryNet                                 1,456,123   1,246,372
# us-gaap_PrepaidExpenseCurrent                           64,961      69,252
# us-gaap_OtherAssetsCurrent                              31,967      26,249
# us-gaap_AssetsCurrent                                2,036,080   2,323,894
# us-gaap_PropertyPlantAndEquipmentNet                 1,065,381     920,773
# us-gaap_OperatingLeaseRightOfUseAsset                1,286,452   1,132,764
# us-gaap_DeferredIncomeTaxAssetsNet                      81,389      56,585
# us-gaap_Goodwill                                        77,307      85,354
# us-gaap_OtherAssetsNoncurrent                          116,407     106,250
# us-gaap_Assets                                       4,663,016   4,625,620
# us-gaap_AccountsPayableCurrent                         508,321     612,512
# us-gaap_AccruedLiabilitiesCurrent                      247,594     319,924
# us-gaap_ContractWithCustomerLiabilityCurrent           479,229     447,770
# us-gaap_AccruedIncomeTaxesCurrent                       61,204      79,554
# us-gaap_OperatingLeaseLiabilityCurrent                 231,965     217,409
# us-gaap_OtherLiabilitiesCurrent                        108,138      94,517
# us-gaap_LiabilitiesCurrent                           1,636,451   1,771,686
# wsm_DeferredLeaseIncentivesLiabilityNoncurrent          10,027      16,360
# us-gaap_OperatingLeaseLiabilityNoncurrent            1,211,693   1,066,839
# us-gaap_OtherLiabilitiesNoncurrent                     103,794     106,528
# us-gaap_Liabilities                                  2,961,965   2,961,413
# us-gaap_PreferredStockValue                                  0           0
# us-gaap_CommonStockValue                                   663         720
# us-gaap_AdditionalPaidInCapital                        573,117     600,942
# us-gaap_RetainedEarningsAccumulatedDeficit           1,141,819   1,074,084
# us-gaap_AccumulatedOtherComprehensiveIncomeLoss...     -13,809     -10,828
# us-gaap_TreasuryStockCommonValue                          -739        -711
# us-gaap_StockholdersEquity                           1,701,051   1,664,207
